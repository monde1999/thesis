# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
def load_image(fn):
    img = cv2.imread(fn)
    img = img[:,:,0]
    print("image shape:", np.shape(img))
    plt.imshow(img)
    plt.show()
    return img
img = load_image("../dataset/depth/0000002-000000033369.png")
# Out:
# image shape: (480, 640)

# %%
def get_histogram(img):
    h,_ = np.histogram(a=img, bins=256, range=(0,255))
    # h[h>3000] = 3000
    h[0] = 0
    plt.plot(h)
    plt.show()
    return h
histogram = get_histogram(img)

# %% [markdown]
#     Algorithm: Global Thresholding Algorithm
#
#     Start
#
#     Chose an initial threshold value T
#
#     Apply T to segment the image leading to two groups of pixels
#
#      R1 are pixels with gray level > T
#
#      R2 are pixels with gray level <= T
#
#     Measure the average gray level values mean1 and mean2 for the pixels in R1 and R2.
#
#     Calculate the new threshold value Tnew = (mean1 + mean2)/2
#
#     Repeat the previous steps till the difference in T is smaller than a pre-defined threshold T0 in the successive iterations
#
#     End

# %%
def get_initial_threshold(img):
    h, _ = np.histogram(a=img, bins=256, range=(0,255))
    h[0] = 0
    m = 1
    n = 255
    while m<n and h[m]==0:
        m+=1
    while n>m and h[n]==0:
        n-=1
    return (m+n)//2

# %%
def get_global_threshold(img):
    t0 = 255
    t1 = get_initial_threshold(img)
    while t1 < t0:
        m1 = img > t1
        m2 = img <= t1
        r1 = img[m1]
        r2 = img[m2]
        mean1 = np.sum(r1)//np.size(r1)
        mean2 = np.sum(r2)//np.size(r2)
        t0 = t1
        t1 = (mean1 + mean2)//2
    return int(t1)

t = get_global_threshold(img)
print(t)
# Out:
# 9

# %%
def segment_image(img, t):
    mask = img > t
    img1 = img.copy()
    img1[mask] = 0
    plt.imshow(img1)
    plt.show()

segment_image(img,t)

# %%
def get_thresholds(img):
    M = 100
    N = 100
    tiles = [img[x:x+M,y:y+N] for x in range(0,img.shape[0],M) for y in range(0,img.shape[1],N)]
    thresholds = set()
    for tile in tiles:
        t = get_global_threshold(tile)
        thresholds.add(t)
    thresholds = list(thresholds)
    list.sort(thresholds, reverse=True)
    if thresholds[0]==255: thresholds.pop(0)
    return thresholds

# %%
def get_global_threshold(img):
    t0 = 255
    t1 = get_initial_threshold(img)
    while t1 < t0:
        m1 = img > t1
        m2 = img <= t1
        r1 = img[m1]
        r2 = img[m2]
        s1 = np.size(r1)
        s2 = np.size(r2)
        if s1==0 or s2==0:
            t1 = t0
            break
        else:
            mean1 = np.sum(r1)//np.size(r1)
            mean2 = np.sum(r2)//np.size(r2)
            t0 = t1
            t1 = (mean1 + mean2)//2
    return int(t1)

# %%
thresholds = get_thresholds(img)
thresholds
# Out:
# [15, 13, 12, 10, 9, 7, 6, 5, 4, 3]

# %%
for t in thresholds:
    print("threshold", t)
    segment_image(img, t)
# Out:
# threshold 15
# threshold 13
# threshold 12
# threshold 10
# threshold 9
# threshold 7
# threshold 6
# threshold 5
# threshold 4
# threshold 3
